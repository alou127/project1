# %% [markdown]
# ### Analysis for WomenTechWomenYes (WTWY) annual gala
#
#
# - Street teams will be placed at entrances to subway stations.
# - Street teams will be collecing email adresses.
# - Those who sign up are sent free tickets to the gala.
# - Placement of street teams at entrances to subway stations will be determined according to MTA data analysis.

# %% [markdown]
# #### Step 1: Cleaning and importing data from http://web.mta.info/developers/turnstile.html
#
# - The data is collected from June 1, 2019 - June 28, 2019

# %%
from __future__ import print_function, division

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import datetime

# %%
# Source: http://web.mta.info/developers/turnstile.html
def get_data(week_nums):
    url = "http://web.mta.info/developers/data/nyct/turnstile/turnstile_{}.txt"
    dfs = []
    for week_num in week_nums:
        file_url = url.format(week_num)
        dfs.append(pd.read_csv(file_url))
    return pd.concat(dfs)
        
week_nums = [190629, 190622, 190615, 190608]
turnstiles_df = get_data(week_nums)

# %%
turnstiles_df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/22/2019  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/22/2019  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/22/2019  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/22/2019  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/22/2019  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  7107725
# 1  REGULAR  7107738
# 2  REGULAR  7107761
# 3  REGULAR  7107858
# 4  REGULAR  7108075
#
#    EXITS
# 0                                            2407457
# 1                                            2407465
# 2                                            2407491
# 3                                            2407541
# 4                                            2407581

# %%
turnstiles_df.columns = [column.strip() for column in turnstiles_df.columns]
turnstiles_df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES', 'EXITS'],
#       dtype='object')

# %%
turnstiles_df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/22/2019  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/22/2019  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/22/2019  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/22/2019  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/22/2019  16:00:00
#
#       DESC  ENTRIES    EXITS
# 0  REGULAR  7107725  2407457
# 1  REGULAR  7107738  2407465
# 2  REGULAR  7107761  2407491
# 3  REGULAR  7107858  2407541
# 4  REGULAR  7108075  2407581

# %%
#4 weeks of data
turnstiles_df.DATE.value_counts().sort_index()
# Out:
# 06/01/2019    29066
# 06/02/2019    28968
# 06/03/2019    30022
# 06/04/2019    29513
# 06/05/2019    29484
# 06/06/2019    29213
# 06/07/2019    28745
# 06/08/2019    29030
# 06/09/2019    29133
# 06/10/2019    29351
# 06/11/2019    29113
# 06/12/2019    30023
# 06/13/2019    29276
# 06/14/2019    29008
# 06/15/2019    29605
# 06/16/2019    29322
# 06/17/2019    29421
# 06/18/2019    29599
# 06/19/2019    29614
# 06/20/2019    29556
# 06/21/2019    30360
# 06/22/2019    29217
# 06/23/2019    29170
# 06/24/2019    29479
# 06/25/2019    29437
# 06/26/2019    29417
# 06/27/2019    29464
# 06/28/2019    29779
# Name: DATE, dtype: int64

# %%
from datetime import datetime as dt

# %%
# Take the date and time fields into a single datetime column
turnstiles_df["DATE_TIME"] = pd.to_datetime(turnstiles_df.DATE + " " + turnstiles_df.TIME, 
                                            format="%m/%d/%Y %H:%M:%S")

# %%
turnstiles_df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/22/2019  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/22/2019  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/22/2019  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/22/2019  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/22/2019  16:00:00
#
#       DESC  ENTRIES    EXITS           DATE_TIME
# 0  REGULAR  7107725  2407457 2019-06-22 00:00:00
# 1  REGULAR  7107738  2407465 2019-06-22 04:00:00
# 2  REGULAR  7107761  2407491 2019-06-22 08:00:00
# 3  REGULAR  7107858  2407541 2019-06-22 12:00:00
# 4  REGULAR  7108075  2407581 2019-06-22 16:00:00

# %%
# Sanity Check to verify that "C/A", "UNIT", "SCP", "STATION", "DATE_TIME" is unique
(turnstiles_df
 .groupby(["C/A", "UNIT", "SCP", "STATION", "DATE_TIME"])
 .ENTRIES.count()
 .reset_index()
 .sort_values("ENTRIES", ascending=False)).head(20)
# Out:
#          C/A  UNIT       SCP         STATION           DATE_TIME  ENTRIES
# 583293  R174  R034  00-00-03          125 ST 2019-06-08 00:00:00        2
# 194099  N045  R187  01-00-02    81 ST-MUSEUM 2019-06-01 17:00:00        2
# 193942  N045  R187  01-00-01    81 ST-MUSEUM 2019-06-02 17:00:00        2
# 194324  N045  R187  01-06-00    81 ST-MUSEUM 2019-06-11 21:00:00        2
# 660217  R249  R179  01-05-00           86 ST 2019-06-27 00:00:00        2
# 679477  R290  R161  00-00-00  KINGSBRIDGE RD 2019-06-07 05:00:00        2
# 660221  R249  R179  01-05-00           86 ST 2019-06-27 04:00:00        2
# 583125  R174  R034  00-00-02          125 ST 2019-06-08 00:00:00        2
# 193937  N045  R187  01-00-01    81 ST-MUSEUM 2019-06-01 17:00:00        2
# 194104  N045  R187  01-00-02    81 ST-MUSEUM 2019-06-02 17:00:00        2
# 660228  R249  R179  01-05-00           86 ST 2019-06-27 12:00:00        2
# 194269  N045  R187  01-06-00    81 ST-MUSEUM 2019-06-02 17:00:00        2
# 660225  R249  R179  01-05-00           86 ST 2019-06-27 08:00:00        2
# 582957  R174  R034  00-00-01          125 ST 2019-06-08 00:00:00        2
# 193777  N045  R187  01-00-00    81 ST-MUSEUM 2019-06-02 17:00:00        2
# 627395  R229  R143  01-00-00           28 ST 2019-06-27 17:00:00        2
# 193772  N045  R187  01-00-00    81 ST-MUSEUM 2019-06-01 17:00:00        2
# 194193  N045  R187  01-00-02    81 ST-MUSEUM 2019-06-17 09:00:00        2
# 548927  R139  R031  04-00-02  34 ST-PENN STA 2019-06-02 08:00:00        1
# 548919  R139  R031  04-00-02  34 ST-PENN STA 2019-06-01 00:00:00        1

# %%
# On 9/16, we seem to have two entries for same time.  Let's take a look
mask = ((turnstiles_df["C/A"] == "N045") & 
(turnstiles_df["UNIT"] == "R187") & 
(turnstiles_df["SCP"] == "01-00-00") & 
(turnstiles_df["STATION"] == "81 ST-MUSEUM") &
(turnstiles_df["DATE_TIME"].dt.date == datetime.datetime(2019, 6, 1).date()))
turnstiles_df[mask].head(10)
# Out:
#         C/A  UNIT       SCP       STATION LINENAME DIVISION        DATE  \
# 48238  N045  R187  01-00-00  81 ST-MUSEUM       BC      IND  06/01/2019
# 48239  N045  R187  01-00-00  81 ST-MUSEUM       BC      IND  06/01/2019
# 48240  N045  R187  01-00-00  81 ST-MUSEUM       BC      IND  06/01/2019
# 48241  N045  R187  01-00-00  81 ST-MUSEUM       BC      IND  06/01/2019
# 48242  N045  R187  01-00-00  81 ST-MUSEUM       BC      IND  06/01/2019
# 48243  N045  R187  01-00-00  81 ST-MUSEUM       BC      IND  06/01/2019
# 48244  N045  R187  01-00-00  81 ST-MUSEUM       BC      IND  06/01/2019
#
#            TIME        DESC  ENTRIES    EXITS           DATE_TIME
# 48238  01:00:00     REGULAR  5253270  6696487 2019-06-01 01:00:00
# 48239  05:00:00     REGULAR  5253277  6696494 2019-06-01 05:00:00
# 48240  09:00:00     REGULAR  5253280  6696548 2019-06-01 09:00:00
# 48241  13:00:00     REGULAR  5253356  6696877 2019-06-01 13:00:00
# 48242  17:00:00     REGULAR  5253806  6697182 2019-06-01 17:00:00
# 48243  17:00:00  RECOVR AUD  5253801  6697182 2019-06-01 17:00:00
# 48244  21:00:00     REGULAR  5254017  6697270 2019-06-01 21:00:00

# %%
# Get rid of the duplicate entry
turnstiles_df.sort_values(["C/A", "UNIT", "SCP", "STATION", "DATE_TIME"], 
                          inplace=True, ascending=False)
turnstiles_df.drop_duplicates(subset=["C/A", "UNIT", "SCP", "STATION", "DATE_TIME"], inplace=True)

# %%
# Sanity Check to verify that "C/A", "UNIT", "SCP", "STATION", "DATE_TIME" is unique
(turnstiles_df
 .groupby(["C/A", "UNIT", "SCP", "STATION", "DATE_TIME"])
 .ENTRIES.count()
 .reset_index()
 .sort_values("ENTRIES", ascending=False)).head()
# Out:
#          C/A  UNIT       SCP         STATION           DATE_TIME  ENTRIES
# 0       A002  R051  02-00-00           59 ST 2019-06-01 00:00:00        1
# 548916  R139  R031  04-00-01  34 ST-PENN STA 2019-06-28 12:00:00        1
# 548906  R139  R031  04-00-01  34 ST-PENN STA 2019-06-26 20:00:00        1
# 548907  R139  R031  04-00-01  34 ST-PENN STA 2019-06-27 00:00:00        1
# 548908  R139  R031  04-00-01  34 ST-PENN STA 2019-06-27 04:00:00        1

# %%
# Drop Exits and Desc Column.  To prevent errors in multiple run of cell, errors on drop is ignored
turnstiles_df = turnstiles_df.drop(["EXITS", "DESC"], axis=1, errors="ignore")

# %%
turnstiles_daily = (turnstiles_df
                        .groupby(["C/A", "UNIT", "SCP", "STATION", "DATE"],as_index=False)
                        .ENTRIES.first())

# %%
turnstiles_daily.head()
# Out:
#     C/A  UNIT       SCP STATION        DATE  ENTRIES
# 0  A002  R051  02-00-00   59 ST  06/01/2019  7080817
# 1  A002  R051  02-00-00   59 ST  06/02/2019  7081567
# 2  A002  R051  02-00-00   59 ST  06/03/2019  7082949
# 3  A002  R051  02-00-00   59 ST  06/04/2019  7084565
# 4  A002  R051  02-00-00   59 ST  06/05/2019  7086109

# %%
turnstiles_daily[["PREV_DATE", "PREV_ENTRIES"]] = (turnstiles_daily
                                                       .groupby(["C/A", "UNIT", "SCP", "STATION"])["DATE", "ENTRIES"]
                                                       .transform(lambda grp: grp.shift(1)))

# %%
turnstiles_daily.head()
# Out:
#     C/A  UNIT       SCP STATION        DATE  ENTRIES   PREV_DATE  PREV_ENTRIES
# 0  A002  R051  02-00-00   59 ST  06/01/2019  7080817         NaN           NaN
# 1  A002  R051  02-00-00   59 ST  06/02/2019  7081567  06/01/2019     7080817.0
# 2  A002  R051  02-00-00   59 ST  06/03/2019  7082949  06/02/2019     7081567.0
# 3  A002  R051  02-00-00   59 ST  06/04/2019  7084565  06/03/2019     7082949.0
# 4  A002  R051  02-00-00   59 ST  06/05/2019  7086109  06/04/2019     7084565.0

# %%
turnstiles_daily.tail()
# Out:
#           C/A  UNIT       SCP        STATION        DATE  ENTRIES   PREV_DATE  \
# 136146  TRAM2  R469  00-05-01  RIT-ROOSEVELT  06/24/2019     5554  06/23/2019
# 136147  TRAM2  R469  00-05-01  RIT-ROOSEVELT  06/25/2019     5554  06/24/2019
# 136148  TRAM2  R469  00-05-01  RIT-ROOSEVELT  06/26/2019     5554  06/25/2019
# 136149  TRAM2  R469  00-05-01  RIT-ROOSEVELT  06/27/2019     5554  06/26/2019
# 136150  TRAM2  R469  00-05-01  RIT-ROOSEVELT  06/28/2019     5554  06/27/2019
#
#         PREV_ENTRIES
# 136146        5554.0
# 136147        5554.0
# 136148        5554.0
# 136149        5554.0
# 136150        5554.0

# %%
# Drop the rows for the earliest date in the df
turnstiles_daily.dropna(subset=["PREV_DATE"], axis=0, inplace=True)

# %%
turnstiles_daily.head()
# Out:
#     C/A  UNIT       SCP STATION        DATE  ENTRIES   PREV_DATE  PREV_ENTRIES
# 1  A002  R051  02-00-00   59 ST  06/02/2019  7081567  06/01/2019     7080817.0
# 2  A002  R051  02-00-00   59 ST  06/03/2019  7082949  06/02/2019     7081567.0
# 3  A002  R051  02-00-00   59 ST  06/04/2019  7084565  06/03/2019     7082949.0
# 4  A002  R051  02-00-00   59 ST  06/05/2019  7086109  06/04/2019     7084565.0
# 5  A002  R051  02-00-00   59 ST  06/06/2019  7087657  06/05/2019     7086109.0

# %%
#create mask for the positive entries to delete neg entries from df. Roughly 1% of data.
positive_entries_mask = turnstiles_daily["ENTRIES"] > turnstiles_daily["PREV_ENTRIES"]
positive_entries_mask
# Out:
# 1          True
# 2          True
# 3          True
# 4          True
# 5          True
# 6          True
# 7          True
# 8          True
# 9          True
# 10         True
# 11         True
# 12         True
# 13         True
# 14         True
# 15         True
# 16         True
# 17         True
# 18         True
# 19         True
# 20         True
# 21         True
# 22         True
# 23         True
# 24         True
# 25         True
# 26         True
# 27         True
# 29         True
# 30         True
# 31         True
#           ...
# 136120    False
# 136121    False
# 136122    False
# 136123    False
# 136125    False
# 136126    False
# 136127    False
# 136128    False
# 136129    False
# 136130    False
# 136131    False
# 136132    False
# 136133    False
# 136134    False
# 136135    False
# 136136    False
# 136137    False
# 136138    False
# 136139    False
# 136140    False
# 136141    False
# 136142    False
# 136143    False
# 136144    False
TRAM2  R469  00-03-01  RIT-ROOSEVELT  06/19/2019  3057886  06/18/2019
# 136088  TRAM2  R469  00-03-01  RIT-ROOSEVELT  06/20/2019  3058083  06/19/2019
# 136089  TRAM2  R469  00-03-01  RIT-ROOSEVELT  06/21/2019  3058337  06/20/2019
# 136090  TRAM2  R469  00-03-01  RIT-ROOSEVELT  06/22/2019  3058727  06/21/2019
# 136091  TRAM2  R469  00-03-01  RIT-ROOSEVELT  06/23/2019  3059109  06/22/2019
# 136092  TRAM2  R469  00-03-01  RIT-ROOSEVELT  06/24/2019  3059424  06/23/2019
# 136093  TRAM2  R469  00-03-01  RIT-ROOSEVELT  06/25/2019  3059619  06/24/2019
# 136094  TRAM2  R469  00-03-01  RIT-ROOSEVELT  06/26/2019  3059981  06/25/2019
# 136095  TRAM2  R469  00-03-01  RIT-ROOSEVELT  06/27/2019  3060280  06/26/2019
# 136096  TRAM2  R469  00-03-01  RIT-ROOSEVELT  06/28/2019  3060669  06/27/2019
# 136098  TRAM2  R469  00-05-00  RIT-ROOSEVELT  06/02/2019     2904  06/01/2019
# 136100  TRAM2  R469  00-05-00  RIT-ROOSEVELT  06/04/2019     2906  06/03/2019
# 136101  TRAM2  R469  00-05-00  RIT-ROOSEVELT  06/05/2019     2907  06/04/2019
# 136103  TRAM2  R469  00-05-00  RIT-ROOSEVELT  06/08/2019     2909  06/06/2019
# 136106  TRAM2  R469  00-05-00  RIT-ROOSEVELT  06/11/2019     2911  06/10/2019
# 136108  TRAM2  R469  00-05-00  RIT-ROOSEVELT  06/13/2019     2912  06/12/2019
# 136110  TRAM2  R469  00-05-00  RIT-ROOSEVELT  06/15/2019     2913  06/14/2019
# 136111  TRAM2  R469  00-05-00  RIT-ROOSEVELT  06/16/2019     2914  06/15/2019
# 136112  TRAM2  R469  00-05-00  RIT-ROOSEVELT  06/17/2019     2915  06/16/2019
# 136113  TRAM2  R469  00-05-00  RIT-ROOSEVELT  06/18/2019     2916  06/17/2019
# 136118  TRAM2  R469  00-05-00  RIT-ROOSEVELT  06/23/2019     2917  06/22/2019
#
#         PREV_ENTRIES
# 1          7080817.0
# 2          7081567.0
# 3          7082949.0
# 4          7084565.0
# 5          7086109.0
# 6          7087657.0
# 7          7089268.0
# 8          7090115.0
# 9          7090874.0
# 10         7092269.0
# 11         7093803.0
# 12         7095407.0
# 13         7096917.0
# 14         7098481.0
# 15         7099426.0
# 16         7100088.0
# 17         7101487.0
# 18         7102924.0
# 19         7104499.0
# 20         7105977.0
# 21         7107508.0
# 22         7108333.0
# 23         7108973.0
# 24         7110324.0
# 25         7111785.0
# 26         7113402.0
# 27         7114951.0
# 29         6305508.0
# 30         6306163.0
# 31         6307308.0
# ...              ...
# 136078     3055321.0
# 136079     3055503.0
# 136080     3055748.0
# 136081     3056019.0
# 136082     3056214.0
# 136083     3056473.0
# 136084     3056912.0
# 136085     3057220.0
# 136086     3057444.0
# 136087     3057651.0
# 136088     3057886.0
# 136089     3058083.0
# 136090     3058337.0
# 136091     3058727.0
# 136092     3059109.0
# 136093     3059424.0
# 136094     3059619.0
# 136095     3059981.0
# 136096     3060280.0
# 136098        2903.0
# 136100        2904.0
# 136101        2906.0
# 136103        2907.0
# 136106        2909.0
# 136108        2911.0
# 136110        2912.0
# 136111        2913.0
# 136112        2914.0
# 136113        2915.0
# 136118        2916.0
#
# [116848 rows x 8 columns]

# %%
def get_daily_counts(row, max_counter):
    counter = row["ENTRIES"] - row["PREV_ENTRIES"]
    
        # Maybe counter is reversed?
    if counter > max_counter:
        print(row["ENTRIES"], row["PREV_ENTRIES"])
        counter = min(row["ENTRIES"], row["PREV_ENTRIES"])
    if counter > max_counter:
        # Check it again to make sure we are not giving a counter that's too big
        return 0
    return counter

# If counter is > 1Million, then the counter might have been reset.  
# Just set it to zero as different counters have different cycle limits
turnstiles_daily["DAILY_ENTRIES"] = turnstiles_daily.apply(get_daily_counts, axis=1, max_counter=800000)
# Out:
# 1376283 8703.0
# 7246468 4050451.0
# 852339 658.0
# 1828703861 9687851.0
# 452993419 1830432.0
# 704681758 2758310.0
# 868286381 101740072.0

# %%
pass

# %%
turnstiles_daily.sort_values('DAILY_ENTRIES',ascending=False)
# Out:
#           C/A  UNIT       SCP          STATION        DATE     ENTRIES  \
# 120709   R501  R054  00-06-01            5 AVE  06/08/2019   136172668
# 120525   R501  R054  00-00-01            5 AVE  06/08/2019     3414803
# 120548   R501  R054  00-00-02            5 AVE  06/08/2019   991388435
# 106062  R238A  R046  02-03-01  GRD CNTRL-42 ST  06/18/2019     1690214
# 106006  R238A  R046  02-00-04  GRD CNTRL-42 ST  06/18/2019     2801644
# 106061  R238A  R046  02-03-01  GRD CNTRL-42 ST  06/17/2019     1679230
# 106013  R238A  R046  02-00-04  GRD CNTRL-42 ST  06/25/2019     2859055
# 105978  R238A  R046  02-00-03  GRD CNTRL-42 ST  06/18/2019     1857402
# 106001  R238A  R046  02-00-04  GRD CNTRL-42 ST  06/13/2019     2764054
# 105999  R238A  R046  02-00-04  GRD CNTRL-42 ST  06/11/2019     2744965
# 106033  R238A  R046  02-03-00  GRD CNTRL-42 ST  06/17/2019   654609515
# 106007  R238A  R046  02-00-04  GRD CNTRL-42 ST  06/19/2019     2811186
# 105992  R238A  R046  02-00-04  GRD CNTRL-42 ST  06/04/2019     2689664
# 106000  R238A  R046  02-00-04  GRD CNTRL-42 ST  06/12/2019     2754409
# 106029  R238A  R046  02-03-00  GRD CNTRL-42 ST  06/13/2019   654582523
# 106014  R238A  R046  02-00-04  GRD CNTRL-42 ST  06/26/2019     2868454
# 105993  R238A  R046  02-00-04  GRD CNTRL-42 ST  06/05/2019     2699054
# 106041  R238A  R046  02-03-00  GRD CNTRL-42 ST  06/25/2019   654666553
# 106015  R238A  R046  02-00-04  GRD CNTRL-42 ST  06/27/2019     2877822
# 105994  R238A  R046  02-00-04  GRD CNTRL-42 ST  06/06/2019     2708394
# 105985  R238A  R046  02-00-03  GRD CNTRL-42 ST  06/25/2019     1901559
# 106005  R238A  R046  02-00-04  GRD CNTRL-42 ST  06/17/2019     2791322
# 105972  R238A  R046  02-00-03  GRD CNTRL-42 ST  06/12/2019     1813373
# 106027  R238A  R046  02-03-00  GRD CNTRL-42 ST  06/11/2019   654564183
# 105998  R238A  R046  02-00-04  GRD CNTRL-42 ST  06/10/2019     2735367
# 106020  R238A  R046  02-03-00  GRD CNTRL-42 ST  06/04/2019   654512561
# 106008  R238A  R046  02-00-04  GRD CNTRL-42 ST  06/20/2019     2820208
# 105987  R238A  R046  02-00-03  GRD CNTRL-42 ST  06/27/2019     1919339
# 106042  R238A  R046  02-03-00  GRD CNTRL-42 ST  06/26/2019   654675525
# 105971  R238A  R046  02-00-03  GRD CNTRL-42 ST  06/11/2019     1804145
# ...       ...   ...       ...              ...         ...         ...
# 22316    H026  R137  00-05-00   MYRTLE-WYCKOFF  06/14/2019        2749
# 22327    H026  R137  00-05-00   MYRTLE-WYCKOFF  06/25/2019        2750
# 131959   R626  R062  00-05-00  CROWN HTS-UTICA  06/03/2019        5923
# 131961   R626  R062  00-05-00  CROWN HTS-UTICA  06/05/2019        5926
# 105987  06/26/2019     1910356.0         8983.0
# 106042  06/25/2019   654666553.0         8972.0
# 105971  06/10/2019     1795221.0         8924.0
# ...            ...           ...            ...
# 22316   06/13/2019        2748.0            1.0
# 22327   06/24/2019        2749.0            1.0
# 131959  06/02/2019        5922.0            1.0
# 131961  06/04/2019        5925.0            1.0
# 131963  06/06/2019        5928.0            1.0
# 131969  06/12/2019        5929.0            1.0
# 131974  06/17/2019        5933.0            1.0
# 131975  06/18/2019        5934.0            1.0
# 131976  06/19/2019        5935.0            1.0
# 85654   06/14/2019          30.0            1.0
# 85682   06/14/2019         140.0            1.0
# 6247    06/05/2019         414.0            1.0
# 6248    06/06/2019         415.0            1.0
# 86015   06/11/2019         159.0            1.0
# 86008   06/04/2019         155.0            1.0
# 85765   06/13/2019         600.0            1.0
# 6266    06/24/2019         429.0            1.0
# 6265    06/23/2019         428.0            1.0
# 6261    06/19/2019         427.0            1.0
# 6258    06/16/2019         426.0            1.0
# 6257    06/15/2019         425.0            1.0
# 6254    06/12/2019         424.0            1.0
# 6251    06/09/2019         418.0            1.0
# 6250    06/08/2019         417.0            1.0
# 6249    06/07/2019         416.0            1.0
# 48185   06/13/2019     9687851.0            0.0
# 17018   06/04/2019     4050451.0            0.0
# 114455  06/18/2019     2758310.0            0.0
# 112818  06/05/2019     1830432.0            0.0
# 123639  06/26/2019   101740072.0            0.0
#
# [116848 rows x 9 columns]

# %%
turnstiles_daily.head()
# Out:
#     C/A  UNIT       SCP STATION        DATE  ENTRIES   PREV_DATE  \
# 1  A002  R051  02-00-00   59 ST  06/02/2019  7081567  06/01/2019
# 2  A002  R051  02-00-00   59 ST  06/03/2019  7082949  06/02/2019
# 3  A002  R051  02-00-00   59 ST  06/04/2019  7084565  06/03/2019
# 4  A002  R051  02-00-00   59 ST  06/05/2019  7086109  06/04/2019
# 5  A002  R051  02-00-00   59 ST  06/06/2019  7087657  06/05/2019
#
#    PREV_ENTRIES  DAILY_ENTRIES
# 1     7080817.0          750.0
# 2     7081567.0         1382.0
# 3     7082949.0         1616.0
# 4     7084565.0         1544.0
# 5     7086109.0         1548.0

# %%
turnstiles_daily['WEEK'] = pd.to_datetime(turnstiles_daily['DATE']).dt.day_name()
turnstiles_daily.head()
# Out:
#     C/A  UNIT       SCP STATION        DATE  ENTRIES   PREV_DATE  \
# 1  A002  R051  02-00-00   59 ST  06/02/2019  7081567  06/01/2019
# 2  A002  R051  02-00-00   59 ST  06/03/2019  7082949  06/02/2019
# 3  A002  R051  02-00-00   59 ST  06/04/2019  7084565  06/03/2019
# 4  A002  R051  02-00-00   59 ST  06/05/2019  7086109  06/04/2019
# 5  A002  R051  02-00-00   59 ST  06/06/2019  7087657  06/05/2019
#
#    PREV_ENTRIES  DAILY_ENTRIES       WEEK
# 1     7080817.0          750.0     Sunday
# 2     7081567.0         1382.0     Monday
# 3     7082949.0         1616.0    Tuesday
# 4     7084565.0         1544.0  Wednesday
# 5     7086109.0         1548.0   Thursday

# %%
#This DF finds the TOTAL entries per day, out of 4 weeks of data
turnstiles_daily_agg = (turnstiles_daily[['STATION','DATE','DAILY_ENTRIES','WEEK']]
                        .groupby('WEEK')
                        .sum()
                        .sort_values('DAILY_ENTRIES',ascending=False)
                       )
#MVP 
turnstiles_daily_agg.reset_index()
# Out:
#         WEEK  DAILY_ENTRIES
# 0  Wednesday     24146457.0
# 1   Thursday     23689416.0
# 2    Tuesday     23118704.0
# 3     Friday     23115087.0
# 4     Monday     22206465.0
# 5     Sunday     10958289.0
# 6   Saturday     10567552.0

# %%
#Dividing of all the weekdays by 4, since we use 4 weeks of data 
turnstiles_daily_agg_trial = turnstiles_daily_agg.iloc[:]/4

# %%
#Diving Saturday by 4/3 since we only have 3 Saturdays by the given period
turnstiles_daily_agg_trial.loc['Saturday'] = turnstiles_daily_agg_trial.loc['Saturday']*4/3

# %%
#MVP for viz 1. This DF has average entries per week day in the last month.
turnstiles_daily_agg_trial
# Out:
#            DAILY_ENTRIES
# WEEK
# Wednesday   6.036614e+06
# Thursday    5.922354e+06
# Tuesday     5.779676e+06
# Friday      5.778772e+06
# Monday      5.551616e+06
# Sunday      2.739572e+06
# Saturday    3.522517e+06

# %%
turnstiles_daily_agg_trial['byMil'] = (turnstiles_daily_agg_trial['DAILY_ENTRIES']/1000000).round(decimals=3)
turnstiles_daily_agg_trial.reset_index()
turnstiles_daily_agg_trial.drop(columns='DAILY_ENTRIES',inplace=True)
turnstiles_daily_agg_trial
# Out:
#            byMil
# WEEK
# Wednesday  6.037
# Thursday   5.922
# Tuesday    5.780
# Friday     5.779
# Monday     5.552
# Sunday     2.740
# Saturday   3.523

# %% [markdown]
# ### EDA Visualizations

# %% [markdown]
# #### EDA 1: Average traffic per week day for the period of June 1, 2019 - June 28, 2018

# %%
import seaborn as sns

# %%
# average traffic per day in the last month
base_color = sns.color_palette()[0]
sns.set(style="darkgrid")
g = turnstiles_daily_agg_trial.plot(kind='bar',figsize=(10,6),color=base_color)
plt.title('Average Foot-Traffic per Day in June',fontdict={'fontsize':20})
plt.xlabel('')
g.get_legend().remove()
plt.ylabel('Number of Entries (Millions)');

# %% [markdown]
# #### Observatiions:
# - Wednesdays has the highest traffic of daily entries on average.
# - The best days to collect signatures will be Wednesdays, Thursdays, Tuesdays, and Fridays.
# - The worst day to collect signatures will will be Sunday.

# %% [markdown]
# ### EDA 2 : Busiest station in NYC

# %%
#test
turnstiles_daily.head()
# Out:
#     C/A  UNIT       SCP STATION        DATE  ENTRIES   PREV_DATE  \
# 1  A002  R051  02-00-00   59 ST  06/02/2019  7081567  06/01/2019
# 2  A002  R051  02-00-00   59 ST  06/03/2019  7082949  06/02/2019
# 3  A002  R051  02-00-00   59 ST  06/04/2019  7084565  06/03/2019
# 4  A002  R051  02-00-00   59 ST  06/05/2019  7086109  06/04/2019
# 5  A002  R051  02-00-00   59 ST  06/06/2019  7087657  06/05/2019
#
#    PREV_ENTRIES  DAILY_ENTRIES       WEEK
# 1     7080817.0          750.0     Sunday
# 2     7081567.0         1382.0     Monday
# 3     7082949.0         1616.0    Tuesday
# 4     7084565.0         1544.0  Wednesday
# 5     7086109.0         1548.0   Thursday

# %%
#grouping data by stations and data to find a sum of daily entries
stations_daily = \
(turnstiles_daily.groupby(['STATION','DATE'])['DAILY_ENTRIES'].sum()
                 .reset_index())  

stations_daily.head()
# Out:
#   STATION        DATE  DAILY_ENTRIES
# 0    1 AV  06/02/2019         5803.0
# 1    1 AV  06/03/2019        17040.0
# 2    1 AV  06/04/2019        17433.0
# 3    1 AV  06/05/2019        19434.0
# 4    1 AV  06/06/2019        18639.0

# %%
#grouping the same data above by stations to find of a sum of daily entires for top 10 stations 
top10_stations = (stations_daily.groupby(['STATION'])['DAILY_ENTRIES'].sum()
                   .reset_index()
                   .sort_values(by='DAILY_ENTRIES',ascending=False) 
                   .STATION.head(10))

top10_stations
# Out:
# 61      34 ST-PENN STA
# 232    GRD CNTRL-42 ST
# 59     34 ST-HERALD SQ
# 46               23 ST
# 352     TIMES SQ-42 ST
# 14      14 ST-UNION SQ
# 225          FULTON ST
# 68     42 ST-PORT AUTH
# 110              86 ST
# 172           CANAL ST
# Name: STATION, dtype: object

# %%
#changing the format to data frame 
stations_daily_top10 = \
    stations_daily[stations_daily['STATION'].isin(top10_stations)]

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=stations_daily_top10, x ='DAILY_ENTRIES',y='STATION',color=base_color)
plt.title('Top 10 busiest stations')
# Out:
# Text(0.5, 1.0, 'Top 10 busiest stations')

# %% [markdown]
# #### Observations:
#
# - The figure above represents top 10 busiest stations in NYC.
# - The busiest station in NYC is 34 ST-PENN STA.
# - Street team should be placed at the enterances of those staions.

# %% [markdown]
# ### EDA 3: Distribution of daily entries in June

# %%
# grouping data by date to find a sum of daily entries 
byDate = turnstiles_daily.groupby('DATE')['DAILY_ENTRIES'].sum().reset_index()

# %%
byDate['byMil'] = (byDate['DAILY_ENTRIES']/1000000).round(decimals=3)

# %%
byDate
# Out:
#           DATE  DAILY_ENTRIES  byMil
# 0   06/02/2019      2737778.0  2.738
# 1   06/03/2019      5649155.0  5.649
# 2   06/04/2019      5683109.0  5.683
# 3   06/05/2019      6004954.0  6.005
# 4   06/06/2019      5895034.0  5.895
# 5   06/07/2019      5801584.0  5.802
# 6   06/08/2019      3598032.0  3.598
# 7   06/09/2019      2807193.0  2.807
# 8   06/10/2019      5408431.0  5.408
# 9   06/11/2019      5826174.0  5.826
# 10  06/12/2019      6110897.0  6.111
# 11  06/13/2019      5977124.0  5.977
# 12  06/14/2019      5861425.0  5.861
# 13  06/15/2019      3464466.0  3.464
# 14  06/16/2019      2566733.0  2.567
# 15  06/17/2019      5570823.0  5.571
# 16  06/18/2019      5849452.0  5.849
# 17  06/19/2019      5963382.0  5.963
# 18  06/20/2019      5922590.0  5.923
# 19  06/21/2019      5750720.0  5.751
# 20  06/22/2019      3505054.0  3.505
# 21  06/23/2019      2846585.0  2.847
# 22  06/24/2019      5578056.0  5.578
# 23  06/25/2019      5759969.0  5.760
# 24  06/26/2019      6067224.0  6.067
# 25  06/27/2019      5894668.0  5.895
# 26  06/28/2019      5701358.0  5.701

# %%
x_labels = ['06/05/2019','06/12/2019','06/19/2019','06/26/2019']

# %%
sns.set(rc={'figure.figsize':(10,5)})
sns.lineplot('DATE','byMil',data=byDate, palette='ch:2.5,.25',sort=False)
plt.xticks(x_labels)
plt.xlabel('')
plt.ylabel('Number of Entries (Millions)', fontdict={'fontsize':15})
plt.title('Entries in June',fontdict={'fontsize':20});

# %% [markdown]
# #### Observations:
# - The peaks of daily entries on the line plot above are on 06/05, 06/12, 06/19, 06/26 - all those days are Wednesdays, which proves observations from EDA 2.
# - The highest peak of daily entries is on 06/12 - second week of the month.
# - The smallest number of daily entries is on 06/09, 06/16, 06/23 - all those dats are Sundays.
